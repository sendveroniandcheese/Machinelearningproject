# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv_path = "clean20152020.csv"

# Import the CSV into a pandas DataFrame
nba_df = pd.read_csv(csv_path, low_memory=False)
nba_df
# Out:
#       year             Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  \
# 0     2018       James Harden  PG   29  HOU  78  78  2867  843  1909  ...
# 1     2016  Russell Westbrook  PG   28  OKC  81  81  2802  824  1941  ...
# 2     2015       James Harden  SG   26  HOU  82  82  3125  710  1617  ...
# 3     2015      Stephen Curry  PG   27  GSW  79  79  2700  805  1598  ...
# 4     2016       James Harden  PG   27  HOU  81  81  2947  674  1533  ...
# ...    ...                ...  ..  ...  ...  ..  ..   ...  ...   ...  ...
# 3164  2015        James Ennis  SF   25  MIA   3   0     7    0     0  ...
# 3165  2015        Erick Green  PG   24  DEN   3   0     7    0     1  ...
# 3166  2015       J.J. O'Brien  SF   23  UTA   2   0     6    0     1  ...
# 3167  2015      Nate Robinson  PG   31  NOP   2   1    23    0     1  ...
# 3168  2015     Jarnell Stokes   C   22  MEM   2   0     4    0     0  ...
#
#       ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS  All Star
# ...

# %%
nba_df.fillna('no', inplace=True)

# %%
nba_df.head(20)
# Out:
#     year              Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...  ORB  \
# 0   2018        James Harden  PG   29  HOU  78  78  2867  843  1909  ...   66
# 1   2016   Russell Westbrook  PG   28  OKC  81  81  2802  824  1941  ...  137
# 2   2015        James Harden  SG   26  HOU  82  82  3125  710  1617  ...   63
# 3   2015       Stephen Curry  PG   27  GSW  79  79  2700  805  1598  ...   68
# 4   2016        James Harden  PG   27  HOU  81  81  2947  674  1533  ...   95
# 5   2017        LeBron James  PF   33  CLE  82  82  3026  857  1580  ...   97
# 6   2016       Isaiah Thomas  PG   27  BOS  76  76  2569  682  1473  ...   43
# 7   2017        James Harden  SG   28  HOU  72  72  2551  651  1449  ...   41
# 8   2018         Paul George  SF   28  OKC  77  77  2841  707  1614  ...  105
# 9   2017       Anthony Davis  PF   24  NOP  75  75  2727  780  1462  ...  187
# 10  2018        Kemba Walker  PG   28  CHO  82  82  2863  731  1684  ...   52
# ...

# %%
result_df = nba_df.sort_values('year')

result_df.head(44)

sorted_df = result_df.sort_values('year')
cleaner_nba = sorted_df.drop_duplicates()


cleaner_nba.to_csv('nba_df.csv', index=False)

# %%
cleaner_nba.rename(columns = {'All Star':'All_Star'}, inplace = True)

# %%
cleaner_nba.All_Star.replace(('Yes', 'no'), (1, 0), inplace=True)

cleaner_nba
# Out:
#       year          Player Pos  Age   Tm   G  GS    MP   FG  FGA  ...  ORB  \
# 3168  2015  Jarnell Stokes   C   22  MEM   2   0     4    0    0  ...    1
# 2302  2015    Jordan McRae  PG   24  TOT  22   1   195   34   78  ...    4
# 2673  2015  Mario Chalmers  PG   29  MIA   6   0   120   10   32  ...    1
# 258   2015   Marcus Morris  SF   26  DET  80  80  2856  410  945  ...   91
# 257   2015  Draymond Green  PF   25  GSW  81  81  2808  401  819  ...  134
# ...    ...             ...  ..  ...  ...  ..  ..   ...  ...  ...  ...  ...
# 2222  2019      Alec Burks  SG   28  PHI  11   0   222   39  100  ...    6
# 872   2019        Rudy Gay  PF   33  SAS  60   5  1287  222  502  ...   56
# 2067  2019     Jae Crowder  SF   29  MIA  13   1   373   50  114  ...    8
# 3067  2019     Matt Mooney  SG   22  CLE   4   0    19    1    4  ...    0
# 2153  2019      Dante Exum  SG   24  CLE  24   1   402   46   96  ...    9
#
#       DRB  TRB  AST  STL  BLK  TOV   PF   PTS  All_Star
# ...
